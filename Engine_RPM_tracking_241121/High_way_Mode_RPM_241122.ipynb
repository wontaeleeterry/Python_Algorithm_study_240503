# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Colormap 에서 1차 성분을 클릭으로 추출한 결과(수작업)

data = pd.read_csv('High_Way_Mode.csv', sep = ',')

# %%
data
# Out:
#        time  speed
# 0        75   1260
# 1       475   1030
# 2       700    890
# 3       975    820
# 4      1125    865
# ..      ...    ...
# 790  364625   2730
# 791  365900   2710
# 792  367975   2590
# 793  369525   2570
# 794  369850   2540
#
# [795 rows x 2 columns]

# %%
plt.plot(data.time, data.speed)

# %%
data_Highway = pd.DataFrame(index=range(0, 369851), columns=['time', 'speed'])

# %%
data_Highway
# Out:
#        time speed
# 0       NaN   NaN
# 1       NaN   NaN
# 2       NaN   NaN
# 3       NaN   NaN
# 4       NaN   NaN
# ...     ...   ...
# 369846  NaN   NaN
# 369847  NaN   NaN
# 369848  NaN   NaN
# 369849  NaN   NaN
# 369850  NaN   NaN
#
# [369851 rows x 2 columns]

# %%
for i in range(0, len(data_Highway)):
    data_Highway.time[i] = i+75
# Out:
# C:\Users\HO\AppData\Local\Temp\ipykernel_3116\1711750358.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data_Highway.time[i] = i+75

# %%
data_Highway
# Out:
#           time speed
# 0           75   NaN
# 1           76   NaN
# 2           77   NaN
# 3           78   NaN
# 4           79   NaN
# ...        ...   ...
# 369846  369921   NaN
# 369847  369922   NaN
# 369848  369923   NaN
# 369849  369924   NaN
# 369850  369925   NaN
#
# [369851 rows x 2 columns]

# %%
for i in range(0, len(data_Highway)):
    for j in range(0, len(data)):
        if data_Highway.time[i] == data.time[j]:
            data_Highway.speed[i] = data.speed[j]
            print("matched (i, j) =", i, j)
            break
# Out:
# C:\Users\HO\AppData\Local\Temp\ipykernel_3116\2053908855.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data_Highway.speed[i] = data.speed[j]
# matched (i, j) = 0 0
# matched (i, j) = 400 1
# matched (i, j) = 625 2
# matched (i, j) = 900 3
# matched (i, j) = 1050 4
# matched (i, j) = 1225 5
# matched (i, j) = 1575 6
# matched (i, j) = 2100 7
# matched (i, j) = 2950 8
# matched (i, j) = 3575 9
# matched (i, j) = 3850 10
# matched (i, j) = 4025 11
# matched (i, j) = 4100 12
# matched (i, j) = 4225 13
# matched (i, j) = 4400 14
# matched (i, j) = 4625 15
# matched (i, j) = 4725 16
# matched (i, j) = 4825 17
# matched (i, j) = 4925 18
# matched (i, j) = 5400 19
# matched (i, j) = 5825 20
# matched (i, j) = 6175 21
# matched (i, j) = 6400 22
# matched (i, j) = 6600 23
# matched (i, j) = 6750 24
# matched (i, j) = 7000 25
# matched (i, j) = 7275 26
# matched (i, j) = 7600 27
# matched (i, j) = 8100 28
# matched (i, j) = 8700 29
# matched (i, j) = 8875 30
# matched (i, j) = 8975 31
# matched (i, j) = 9050 32
# matched (i, j) = 9225 33
# matched (i, j) = 9400 34
# matched (i, j) = 9750 35
# matched (i, j) = 10100 36
# matched (i, j) = 10700 37
# matched (i, j) = 11275 38
# matched (i, j) = 11525 39
# matched (i, j) = 11950 40
# matched (i, j) = 12700 41
# matched (i, j) = 12925 42
# matched (i, j) = 13000 43
# matched (i, j) = 13200 44
# matched (i, j) = 13525 45
# matched (i, j) = 13675 46
# matched (i, j) = 13800 47
# matched (i, j) = 13925 48
# matched (i, j) = 14050 49
# matched (i, j) = 14150 50
# matched (i, j) = 14425 51
# matched (i, j) = 14600 52
# matched (i, j) = 14800 53
# matched (i, j) = 14875 54
# matched (i, j) = 15000 55
# matched (i, j) = 15200 56
# matched (i, j) = 15550 57
# matched (i, j) = 15950 58
# matched (i, j) = 16100 59
# matched (i, j) = 16350 60
# matched (i, j) = 16950 61
# matched (i, j) = 17675 62
# matched (i, j) = 18300 63
# matched (i, j) = 18550 64
# matched (i, j) = 18700 65
# matched (i, j) = 18850 66
# matched (i, j) = 19025 67
# matched (i, j) = 19325 68
# matched (i, j) = 19600 69
# matched (i, j) = 19725 70
# matched (i, j) = 19950 71
# matched (i, j) = 20050 72
# matched (i, j) = 20200 73
# matched (i, j) = 20425 74
# matched (i, j) = 20575 75
# matched (i, j) = 20775 76
# matched (i, j) = 21050 77
# matched (i, j) = 21525 78
# matched (i, j) = 21850 79
# matched (i, j) = 22075 80
# matched (i, j) = 22200 81
# matched (i, j) = 22325 82
# matched (i, j) = 22450 83
# matched (i, j) = 22550 84
# matched (i, j) = 22625 85
# matched (i, j) = 22675 86
# matched (i, j) = 22950 87
# matched (i, j) = 23175 88
# matched (i, j) = 23325 89
# matched (i, j) = 23525 90
# matched (i, j) = 23625 91
# matched (i, j) = 23825 92
# matched (i, j) = 24100 93
# matched (i, j) = 24350 94
# matched (i, j) = 24675 95
# matched (i, j) = 24925 96
# matched (i, j) = 25350 97
# matched (i, j) = 25600 98
# matched (i, j) = 25700 99
# matched (i, j) = 25900 100
# matched (i, j) = 26050 101
# matched (i, j) = 26225 102
# matched (i, j) = 26425 103
# matched (i, j) = 26875 104
# matched (i, j) = 27625 105
# matched (i, j) = 27900 106
# matched (i, j) = 28175 107
# matched (i, j) = 28625 108
# matched (i, j) = 28925 109
# matched (i, j) = 29125 110
# matched (i, j) = 29250 111
# matched (i, j) = 29450 112
# matched (i, j) = 30300 113
# matched (i, j) = 31225 114
# matched (i, j) = 31775 115
# matched (i, j) = 32025 116
# matched (i, j) = 32275 117
# matched (i, j) = 32575 118
# matched (i, j) = 32775 119
# matched (i, j) = 33025 120
# matched (i, j) = 33300 121
# matched (i, j) = 33700 122
# matched (i, j) = 33975 123
# matched (i, j) = 34125 124
# matched (i, j) = 34175 125
# matched (i, j) = 34325 126
# matched (i, j) = 34500 127
# matched (i, j) = 34800 128
# matched (i, j) = 35200 129
# matched (i, j) = 35500 130
# matched (i, j) = 35875 131
# matched (i, j) = 36200 132
# matched (i, j) = 36475 133
# matched (i, j) = 36625 134
# matched (i, j) = 36775 135
# matched (i, j) = 37100 136
# matched (i, j) = 37300 137
# matched (i, j) = 37625 138
# matched (i, j) = 37825 139
# matched (i, j) = 37950 140
# matched (i, j) = 38150 141
# matched (i, j) = 38425 142
# matched (i, j) = 38625 143
# matched (i, j) = 38775 144
# matched (i, j) = 39225 145
# matched (i, j) = 39750 146
# matched (i, j) = 40425 147
# matched (i, j) = 40775 148
# matched (i, j) = 41025 149
# matched (i, j) = 41325 150
# matched (i, j) = 41675 151
# matched (i, j) = 42525 152
# matched (i, j) = 43150 153
# matched (i, j) = 43825 154
# matched (i, j) = 44350 155
# matched (i, j) = 44800 156
# matched (i, j) = 50300 157
# matched (i, j) = 50550 158
# matched (i, j) = 50875 159
# matched (i, j) = 50950 160
# matched (i, j) = 51150 161
# matched (i, j) = 51475 162
# matched (i, j) = 51700 163
# matched (i, j) = 51850 164
# matched (i, j) = 52050 165
# matched (i, j) = 52125 166
# matched (i, j) = 52400 167
# matched (i, j) = 52600 168
# matched (i, j) = 52675 169
# matched (i, j) = 52825 170
# matched (i, j) = 53300 171
# matched (i, j) = 53725 172
# matched (i, j) = 54125 173
# matched (i, j) = 54475 174
# matched (i, j) = 54800 175
# matched (i, j) = 55050 176
# matched (i, j) = 55725 177
# matched (i, j) = 56375 178
# matched (i, j) = 56825 179
# matched (i, j) = 57000 180
# matched (i, j) = 57250 181
# matched (i, j) = 57600 182
# matched (i, j) = 58000 183
# matched (i, j) = 58175 184
# matched (i, j) = 58450 185
# matched (i, j) = 58550 186
# matched (i, j) = 58800 187
# matched (i, j) = 59100 188
# matched (i, j) = 59725 189
# matched (i, j) = 60050 190
# matched (i, j) = 60700 191
# matched (i, j) = 61350 192
# matched (i, j) = 61675 193
# matched (i, j) = 62050 194
# matched (i, j) = 62200 195
# matched (i, j) = 62350 196
# matched (i, j) = 62650 197
# matched (i, j) = 63075 198
# matched (i, j) = 63250 199
# matched (i, j) = 63850 200
# matched (i, j) = 64675 201
# matched (i, j) = 65425 202
# matched (i, j) = 65525 203
# matched (i, j) = 65675 204
# matched (i, j) = 65800 205
# matched (i, j) = 66250 206
# matched (i, j) = 66675 207
# matched (i, j) = 67050 208
# matched (i, j) = 67350 209
# matched (i, j) = 67825 210
# matched (i, j) = 68175 211
# matched (i, j) = 68475 212
# matched (i, j) = 68700 213
# matched (i, j) = 68950 214
# matched (i, j) = 69350 215
# matched (i, j) = 69775 216
# matched (i, j) = 70100 217
# matched (i, j) = 70275 218
# matched (i, j) = 70500 219
# matched (i, j) = 70700 220
# matched (i, j) = 70825 221
# matched (i, j) = 71275 222
# matched (i, j) = 72275 223
# matched (i, j) = 73350 224
# matched (i, j) = 74175 225
# matched (i, j) = 74375 226
# matched (i, j) = 74975 227
# matched (i, j) = 75525 228
# matched (i, j) = 75950 229
# matched (i, j) = 76300 230
# matched (i, j) = 76600 231
# matched (i, j) = 77175 232
# matched (i, j) = 78175 233
# matched (i, j) = 79275 234
# matched (i, j) = 79725 235
# matched (i, j) = 81750 236
# matched (i, j) = 82800 237
# matched (i, j) = 83225 238
# matched (i, j) = 83525 239
# matched (i, j) = 83775 240
# matched (i, j) = 83975 241
# matched (i, j) = 84200 242
# matched (i, j) = 84375 243
# matched (i, j) = 84550 244
# matched (i, j) = 84850 245
# matched (i, j) = 85225 246
# matched (i, j) = 85400 247
# matched (i, j) = 85625 248
# matched (i, j) = 85925 249
# matched (i, j) = 86150 250
# matched (i, j) = 86700 251
# matched (i, j) = 87050 252
# matched (i, j) = 87225 253
# matched (i, j) = 87575 254
# matched (i, j) = 87825 255
# matched (i, j) = 88150 256
# matched (i, j) = 88575 257
# matched (i, j) = 88800 258
# matched (i, j) = 89075 259
# matched (i, j) = 89325 260
# matched (i, j) = 89650 261
# matched (i, j) = 90000 262
# matched (i, j) = 90225 263
# matched (i, j) = 90375 264
# matched (i, j) = 90800 265
# matched (i, j) = 91175 266
# matched (i, j) = 91525 267
# matched (i, j) = 92050 268
# matched (i, j) = 92750 269
# matched (i, j) = 93250 270
# matched (i, j) = 93875 271
# matched (i, j) = 94375 272
# matched (i, j) = 94725 273
# matched (i, j) = 95025 274
# matched (i, j) = 95225 275
# matched (i, j) = 95350 276
# matched (i, j) = 95575 277
# matched (i, j) = 95825 278
# matched (i, j) = 96250 279
# matched (i, j) = 96525 280
# matched (i, j) = 96825 281
# matched (i, j) = 97075 282
# matched (i, j) = 97300 283
# matched (i, j) = 97600 284
# matched (i, j) = 98350 285
# matched (i, j) = 98975 286
# matched (i, j) = 99275 287
# matched (i, j) = 99425 288
# matched (i, j) = 99750 289
# matched (i, j) = 100350 290
# matched (i, j) = 100825 291
# matched (i, j) = 101275 292
# matched (i, j) = 101625 293
# matched (i, j) = 101975 294
# matched (i, j) = 102500 295
# matched (i, j) = 102925 296
# matched (i, j) = 103450 297
# matched (i, j) = 104375 298
# matched (i, j) = 105675 299
# matched (i, j) = 106050 300
# matched (i, j) = 106300 301
# matched (i, j) = 106575 302
# matched (i, j) = 106800 303
# matched (i, j) = 107025 304
# matched (i, j) = 107150 305
# matched (i, j) = 107375 306
# matched (i, j) = 107675 307
# matched (i, j) = 107925 308
# matched (i, j) = 108225 309
# matched (i, j) = 108375 310
# matched (i, j) = 108600 311
# matched (i, j) = 108775 312
# matched (i, j) = 109050 313
# matched (i, j) = 109250 314
# matched (i, j) = 109725 315
# matched (i, j) = 110175 316
# matched (i, j) = 110325 317
# matched (i, j) = 110550 318
# matched (i, j) = 110825 319
# matched (i, j) = 110950 320
# matched (i, j) = 111350 321
# matched (i, j) = 111550 322
# matched (i, j) = 111825 323
# matched (i, j) = 112200 324
# matched (i, j) = 112775 325
# matched (i, j) = 113175 326
# matched (i, j) = 113625 327
# matched (i, j) = 113900 328
# matched (i, j) = 114575 329
# matched (i, j) = 115125 330
# matched (i, j) = 115500 331
# matched (i, j) = 116100 332
# matched (i, j) = 116650 333
# matched (i, j) = 117250 334
# matched (i, j) = 118125 335
# matched (i, j) = 118900 336
# matched (i, j) = 120650 337
# matched (i, j) = 121075 338
# matched (i, j) = 121500 339
# matched (i, j) = 121725 340
# matched (i, j) = 122075 341
# matched (i, j) = 122250 342
# matched (i, j) = 122500 343
# matched (i, j) = 122925 344
# matched (i, j) = 123325 345
# matched (i, j) = 123700 346
# matched (i, j) = 123875 347
# matched (i, j) = 124250 348
# matched (i, j) = 124600 349
# matched (i, j) = 124750 350
# matched (i, j) = 125350 351
# matched (i, j) = 126275 352
# matched (i, j) = 127650 353
# matched (i, j) = 128850 354
# matched (i, j) = 129325 355
# matched (i, j) = 129925 356
# matched (i, j) = 130275 357
# matched (i, j) = 130475 358
# matched (i, j) = 130775 359
# matched (i, j) = 132350 360
# matched (i, j) = 134675 361
# matched (i, j) = 136225 362
# matched (i, j) = 137625 363
# matched (i, j) = 138350 364
# matched (i, j) = 138750 365
# matched (i, j) = 139250 366
# matched (i, j) = 139625 367
# matched (i, j) = 139825 368
# matched (i, j) = 140125 369
# matched (i, j) = 140400 370
# matched (i, j) = 140600 371
# matched (i, j) = 140775 372
# matched (i, j) = 140975 373
# matched (i, j) = 141175 374
# matched (i, j) = 141350 375
# matched (i, j) = 141775 376
# matched (i, j) = 142325 377
# matched (i, j) = 142575 378
# matched (i, j) = 142825 379
# matched (i, j) = 143075 380
# matched (i, j) = 143725 381
# matched (i, j) = 144250 382
# matched (i, j) = 145150 383
# matched (i, j) = 145800 384
# matched (i, j) = 146100 385
# matched (i, j) = 146425 386
# matched (i, j) = 146800 387
# matched (i, j) = 147275 388
# matched (i, j) = 147675 389
# matched (i, j) = 148075 390
# matched (i, j) = 148825 391
# matched (i, j) = 149500 392
# matched (i, j) = 150600 393
# matched (i, j) = 151125 394
# matched (i, j) = 152150 395
# matched (i, j) = 153000 396
# matched (i, j) = 153250 397
# matched (i, j) = 153325 398
# matched (i, j) = 153500 399
# matched (i, j) = 153775 400
# matched (i, j) = 154000 401
# matched (i, j) = 154325 402
# matched (i, j) = 154600 403
# matched (i, j) = 154775 404
# matched (i, j) = 154925 405
# matched (i, j) = 155225 406
# matched (i, j) = 155525 407
# matched (i, j) = 155975 408
# matched (i, j) = 156550 409
# matched (i, j) = 156725 410
# matched (i, j) = 157000 411
# matched (i, j) = 157225 412
# matched (i, j) = 157500 413
# matched (i, j) = 157775 414
# matched (i, j) = 158500 415
# matched (i, j) = 159300 416
# matched (i, j) = 159600 417
# matched (i, j) = 160050 418
# matched (i, j) = 160425 419
# matched (i, j) = 160725 420
# matched (i, j) = 160925 421
# matched (i, j) = 161150 422
# matched (i, j) = 161225 423
# matched (i, j) = 161325 424
# matched (i, j) = 161600 425
# matched (i, j) = 161775 426
# matched (i, j) = 161975 427
# matched (i, j) = 162250 428
# matched (i, j) = 162650 429
# matched (i, j) = 163025 430
# matched (i, j) = 163475 431
# matched (i, j) = 163625 432
# matched (i, j) = 163725 433
# matched (i, j) = 163925 434
# matched (i, j) = 164125 435
# matched (i, j) = 164275 436
# matched (i, j) = 164550 437
# matched (i, j) = 165075 438
# matched (i, j) = 165775 439
# matched (i, j) = 167175 440
# matched (i, j) = 168200 441
# matched (i, j) = 168500 442
# matched (i, j) = 168775 443
# matched (i, j) = 169050 444
# matched (i, j) = 169650 445
# matched (i, j) = 170275 446
# matched (i, j) = 170450 447
# matched (i, j) = 170875 448
# matched (i, j) = 171275 449
# matched (i, j) = 171575 450
# matched (i, j) = 171775 451
# matched (i, j) = 171850 452
# matched (i, j) = 172100 453
# matched (i, j) = 172500 454
# matched (i, j) = 172750 455
# matched (i, j) = 173025 456
# matched (i, j) = 173300 457
# matched (i, j) = 173600 458
# matched (i, j) = 174025 459
# matched (i, j) = 174800 460
# matched (i, j) = 175475 461
# matched (i, j) = 176050 462
# matched (i, j) = 176525 463
# matched (i, j) = 177025 464
# matched (i, j) = 177500 465
# matched (i, j) = 178000 466
# matched (i, j) = 178500 467
# matched (i, j) = 178850 468
# matched (i, j) = 179350 469
# matched (i, j) = 180300 470
# matched (i, j) = 180900 471
# matched (i, j) = 181925 472
# matched (i, j) = 182825 473
# matched (i, j) = 182925 474
# matched (i, j) = 183100 475
# matched (i, j) = 183350 476
# matched (i, j) = 183650 477
# matched (i, j) = 184225 478
# matched (i, j) = 184600 479
# matched (i, j) = 184950 480
# matched (i, j) = 185150 481
# matched (i, j) = 185275 482
# matched (i, j) = 185375 483
# matched (i, j) = 185650 484
# matched (i, j) = 185800 485
# matched (i, j) = 186025 486
# matched (i, j) = 186325 487
# matched (i, j) = 186725 488
# matched (i, j) = 187275 489
# matched (i, j) = 187650 490
# matched (i, j) = 188125 491
# matched (i, j) = 188525 492
# matched (i, j) = 188800 493
# matched (i, j) = 189925 494
# matched (i, j) = 190375 495
# matched (i, j) = 190850 496
# matched (i, j) = 191300 497
# matched (i, j) = 191775 498
# matched (i, j) = 191975 499
# matched (i, j) = 192125 500
# matched (i, j) = 192225 501
# matched (i, j) = 192500 502
# matched (i, j) = 193275 503
# matched (i, j) = 194325 504
# matched (i, j) = 195175 505
# matched (i, j) = 195350 506
# matched (i, j) = 195700 507
# matched (i, j) = 196125 508
# matched (i, j) = 196650 509
# matched (i, j) = 197150 510
# matched (i, j) = 197500 511
# matched (i, j) = 198025 512
# matched (i, j) = 198425 513
# matched (i, j) = 198975 514
# matched (i, j) = 199325 515
# matched (i, j) = 199575 516
# matched (i, j) = 199750 517
# matched (i, j) = 200025 518
# matched (i, j) = 200300 519
# matched (i, j) = 200575 520
# matched (i, j) = 200825 521
# matched (i, j) = 200975 522
# matched (i, j) = 201175 523
# matched (i, j) = 201525 524
# matched (i, j) = 201950 525
# matched (i, j) = 202200 526
# matched (i, j) = 202275 527
# matched (i, j) = 202450 528
# matched (i, j) = 202700 529
# matched (i, j) = 202925 530
# matched (i, j) = 203150 531
# matched (i, j) = 203575 532
# matched (i, j) = 204075 533
# matched (i, j) = 204375 534
# matched (i, j) = 204575 535
# matched (i, j) = 204900 536
# matched (i, j) = 205200 537
# matched (i, j) = 205575 538
# matched (i, j) = 206675 539
# matched (i, j) = 208400 540
# matched (i, j) = 208725 541
# matched (i, j) = 209000 542
# matched (i, j) = 209275 543
# matched (i, j) = 209450 544
# matched (i, j) = 209950 545
# matched (i, j) = 210800 546
# matched (i, j) = 212050 547
# matched (i, j) = 213550 548
# matched (i, j) = 214700 549
# matched (i, j) = 215075 550
# matched (i, j) = 215450 551
# matched (i, j) = 215900 552
# matched (i, j) = 216275 553
# matched (i, j) = 216375 554
# matched (i, j) = 216825 555
# matched (i, j) = 217325 556
# matched (i, j) = 217825 557
# matched (i, j) = 218600 558
# matched (i, j) = 219300 559
# matched (i, j) = 219700 560
# matched (i, j) = 219925 561
# matched (i, j) = 220200 562
# matched (i, j) = 220325 563
# matched (i, j) = 220450 564
# matched (i, j) = 220850 565
# matched (i, j) = 221425 566
# matched (i, j) = 221875 567
# matched (i, j) = 222175 568
# matched (i, j) = 222200 569
# matched (i, j) = 222475 570
# matched (i, j) = 223125 571
# matched (i, j) = 223350 572
# matched (i, j) = 223675 573
# matched (i, j) = 224175 574
# matched (i, j) = 224475 575
# matched (i, j) = 224925 576
# matched (i, j) = 225125 577
# matched (i, j) = 225375 578
# matched (i, j) = 225550 579
# matched (i, j) = 225725 580
# matched (i, j) = 226000 581
# matched (i, j) = 226325 582
# matched (i, j) = 226900 583
# matched (i, j) = 227275 584
# matched (i, j) = 227500 585
# matched (i, j) = 228000 586
# matched (i, j) = 228675 587
# matched (i, j) = 229125 588
# matched (i, j) = 229425 589
# matched (i, j) = 229775 590
# matched (i, j) = 230075 591
# matched (i, j) = 230375 592
# matched (i, j) = 230825 593
# matched (i, j) = 231050 594
# matched (i, j) = 231225 595
# matched (i, j) = 231450 596
# matched (i, j) = 231725 597
# matched (i, j) = 232025 598
# matched (i, j) = 232125 599
# matched (i, j) = 232425 600
# matched (i, j) = 232700 601
# matched (i, j) = 232925 602
# matched (i, j) = 233100 603
# matched (i, j) = 233425 604
# matched (i, j) = 233675 605
# matched (i, j) = 234250 606
# matched (i, j) = 235225 607
# matched (i, j) = 235925 608
# matched (i, j) = 236325 609
# matched (i, j) = 236675 610
# matched (i, j) = 236975 611
# matched (i, j) = 238000 612
# matched (i, j) = 239050 613
# matched (i, j) = 239675 614
# matched (i, j) = 240775 615
# matched (i, j) = 241875 616
# matched (i, j) = 242325 617
# matched (i, j) = 242650 618
# matched (i, j) = 243000 619
# matched (i, j) = 243375 620
# matched (i, j) = 243600 621
# matched (i, j) = 244125 622
# matched (i, j) = 244600 623
# matched (i, j) = 245150 624
# matched (i, j) = 245550 625
# matched (i, j) = 245650 626
# matched (i, j) = 246025 627
# matched (i, j) = 246375 628
# matched (i, j) = 246875 629
# matched (i, j) = 247700 630
# matched (i, j) = 248150 631
# matched (i, j) = 248675 632
# matched (i, j) = 249575 633
# matched (i, j) = 249925 634
# matched (i, j) = 250575 635
# matched (i, j) = 250825 636
# matched (i, j) = 251125 637
# matched (i, j) = 251400 638
# matched (i, j) = 251500 639
# matched (i, j) = 252100 640
# matched (i, j) = 252575 641
# matched (i, j) = 252650 642
# matched (i, j) = 253000 643
# matched (i, j) = 253075 644
# matched (i, j) = 253250 645
# matched (i, j) = 253550 646
# matched (i, j) = 253775 647
# matched (i, j) = 254200 648
# matched (i, j) = 254725 649
# matched (i, j) = 255150 650
# matched (i, j) = 255650 651
# matched (i, j) = 256200 652
# matched (i, j) = 256575 653
# matched (i, j) = 257025 654
# matched (i, j) = 257450 655
# matched (i, j) = 258100 656
# matched (i, j) = 258700 657
# matched (i, j) = 258925 658
# matched (i, j) = 259250 659
# matched (i, j) = 259675 660
# matched (i, j) = 260075 661
# matched (i, j) = 260300 662
# matched (i, j) = 260550 663
# matched (i, j) = 261175 664
# matched (i, j) = 261650 665
# matched (i, j) = 262500 666
# matched (i, j) = 262750 667
# matched (i, j) = 263150 668
# matched (i, j) = 263375 669
# matched (i, j) = 263950 670
# matched (i, j) = 264500 671
# matched (i, j) = 264575 672
# matched (i, j) = 264925 673
# matched (i, j) = 265125 674
# matched (i, j) = 265325 675
# matched (i, j) = 266075 676
# matched (i, j) = 266300 677
# matched (i, j) = 266600 678
# matched (i, j) = 266900 679
# matched (i, j) = 267250 680
# matched (i, j) = 267450 681
# matched (i, j) = 267700 682
# matched (i, j) = 268200 683
# matched (i, j) = 268850 684
# matched (i, j) = 269325 685
# matched (i, j) = 269575 686
# matched (i, j) = 270100 687
# matched (i, j) = 271225 688
# matched (i, j) = 273375 689
# matched (i, j) = 276100 690
# matched (i, j) = 278400 691
# matched (i, j) = 279750 692
# matched (i, j) = 283400 693
# matched (i, j) = 284025 694
# matched (i, j) = 286100 695
# matched (i, j) = 287825 696
# matched (i, j) = 289625 697
# matched (i, j) = 290225 698
# matched (i, j) = 290800 699
# matched (i, j) = 291275 700
# matched (i, j) = 291750 701
# matched (i, j) = 292025 702
# matched (i, j) = 292200 703
# matched (i, j) = 292475 704
# matched (i, j) = 292825 705
# matched (i, j) = 293025 706
# matched (i, j) = 293275 707
# matched (i, j) = 293825 708
# matched (i, j) = 294300 709
# matched (i, j) = 294775 710
# matched (i, j) = 294975 711
# matched (i, j) = 295575 712
# matched (i, j) = 296275 713
# matched (i, j) = 296575 714
# matched (i, j) = 297200 715
# matched (i, j) = 298075 716
# matched (i, j) = 299250 717
# matched (i, j) = 299675 718
# matched (i, j) = 302075 719
# matched (i, j) = 304050 720
# matched (i, j) = 305225 721
# matched (i, j) = 306625 722
# matched (i, j) = 307675 723
# matched (i, j) = 308200 724
# matched (i, j) = 308550 725
# matched (i, j) = 308900 726
# matched (i, j) = 309575 727
# matched (i, j) = 309750 728
# matched (i, j) = 310075 729
# matched (i, j) = 310625 730
# matched (i, j) = 311125 731
# matched (i, j) = 311875 732
# matched (i, j) = 312475 733
# matched (i, j) = 313125 734
# matched (i, j) = 313800 735
# matched (i, j) = 314375 736
# matched (i, j) = 314875 737
# matched (i, j) = 315650 738
# matched (i, j) = 315800 739
# matched (i, j) = 316525 740
# matched (i, j) = 317325 741
# matched (i, j) = 317550 742
# matched (i, j) = 318125 743
# matched (i, j) = 318550 744
# matched (i, j) = 319100 745
# matched (i, j) = 319675 746
# matched (i, j) = 320225 747
# matched (i, j) = 320700 748
# matched (i, j) = 321300 749
# matched (i, j) = 322325 750
# matched (i, j) = 323625 751
# matched (i, j) = 324625 752
# matched (i, j) = 325475 753
# matched (i, j) = 326275 754
# matched (i, j) = 327100 755
# matched (i, j) = 327525 756
# matched (i, j) = 328000 757
# matched (i, j) = 328500 758
# matched (i, j) = 329025 759
# matched (i, j) = 329625 760
# matched (i, j) = 330225 761
# matched (i, j) = 330700 762
# matched (i, j) = 330850 763
# matched (i, j) = 331350 764
# matched (i, j) = 332150 765
# matched (i, j) = 333400 766
# matched (i, j) = 334200 767
# matched (i, j) = 334575 768
# matched (i, j) = 335225 769
# matched (i, j) = 335975 770
# matched (i, j) = 337125 771
# matched (i, j) = 338375 772
# matched (i, j) = 339400 773
# matched (i, j) = 339875 774
# matched (i, j) = 340950 775
# matched (i, j) = 341525 776
# matched (i, j) = 341750 777
# matched (i, j) = 342100 778
# matched (i, j) = 342350 779
# matched (i, j) = 342425 780
# matched (i, j) = 343500 781
# matched (i, j) = 344650 782
# matched (i, j) = 348625 783
# matched (i, j) = 355375 784
# matched (i, j) = 361325 785
# matched (i, j) = 361625 786
# matched (i, j) = 362300 787
# matched (i, j) = 362825 788
# matched (i, j) = 363875 789
# matched (i, j) = 364550 790
# matched (i, j) = 365825 791
# matched (i, j) = 367900 792
# matched (i, j) = 369450 793
# matched (i, j) = 369775 794

# %%
#data_city.to_excel("City_Mode_temp.xlsx")
data_Highway.to_csv("data_Highway_temp.csv")

# %%
data_Highway.tail()
# Out:
#           time speed
# 369846  369921   NaN
# 369847  369922   NaN
# 369848  369923   NaN
# 369849  369924   NaN
# 369850  369925   NaN

# %%
#### 앞에 확정된 i 값을 기억하여 -> 다음 루프에서는 그 뒤에 값만 검색하는 알고리즘으로 수정 -> 반복 속도 향상
# 처음부터 다시 시작할 필요가 없다.

# j가 950이 될 때까지 계속 실행
# 결측치 부분 확인 - 49만개 데이터 중 결측치는 아래 선형보간법으로 채우기

# data_city.time[100]
# Out:
# 200

# %%
# 데이터프레임 복사

data_Highway_copy = data_Highway.copy()

# %%
data_Highway_copy
# Out:
#           time speed
# 0           75  1260
# 1           76   NaN
# 2           77   NaN
# 3           78   NaN
# 4           79   NaN
# ...        ...   ...
# 369846  369921   NaN
# 369847  369922   NaN
# 369848  369923   NaN
# 369849  369924   NaN
# 369850  369925   NaN
#
# [369851 rows x 2 columns]

# %%
data_Highway_copy.speed[369700:369776]
# Out:
# 369700     NaN
# 369701     NaN
# 369702     NaN
# 369703     NaN
# 369704     NaN
#           ...
# 369771     NaN
# 369772     NaN
# 369773     NaN
# 369774     NaN
# 369775    2540
# Name: speed, Length: 76, dtype: object

# %%
data_Highway_final = data_Highway_copy.loc[0:369775, 'time': 'speed']
data_Highway_final
# Out:
#           time speed
# 0           75  1260
# 1           76   NaN
# 2           77   NaN
# 3           78   NaN
# 4           79   NaN
# ...        ...   ...
# 369771  369846   NaN
# 369772  369847   NaN
# 369773  369848   NaN
# 369774  369849   NaN
# 369775  369850  2540
#
# [369776 rows x 2 columns]

# %%
# 여러개의 결측치를 선형보간법으로 채우기

data_Highway_final['speed'] = data_Highway_final['speed'].interpolate(method = 'polynomial', order=2)
# Out:
# C:\Users\HO\AppData\Local\Temp\ipykernel_3116\4273960810.py:3: FutureWarning: Series.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data_Highway_final['speed'] = data_Highway_final['speed'].interpolate(method = 'polynomial', order=2)

# %%
data_Highway_final
# Out:
#           time speed
# 0           75  1260
# 1           76   NaN
# 2           77   NaN
# 3           78   NaN
# 4           79   NaN
# ...        ...   ...
# 369771  369846   NaN
# 369772  369847   NaN
# 369773  369848   NaN
# 369774  369849   NaN
# 369775  369850  2540
#
# [369776 rows x 2 columns]

# %%
# 소수점 둘째자리까지 정리 (241122)

column = 'speed'
where = 2

data_Highway_final[column]= round(data_Highway_final[column], where)

# %%
import numpy as np

plt.figure(figsize=(15,5))

plt.yticks(np.arange(0, 4001, 200))
plt.xticks(np.arange(0, 470001, 30000))

plt.plot(data_Highway_final.time, data_Highway_final.speed)

plt.title('City Mode')
plt.xlabel('Time (msec)')
plt.ylabel('TC Speed (Hz)')
plt.xlim([0, 470000])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 4000])     # Y축의 범위: [ymin, ymax]
plt.grid(True, linestyle='--')
plt.show()

# %%
data_city_temp_final.to_csv("City_Mode_final.csv")
