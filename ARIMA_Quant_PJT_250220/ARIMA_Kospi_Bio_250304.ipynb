# %%
from pandas import DataFrame
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import FinanceDataReader as fdr

df_krx = fdr.StockListing('KRX')
print(len(df_krx))
df_krx.head()
# Out:
# 2873
#      Code        ISU_CD      Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI         54500          3        0
# 1  000660  KR7000660001    SK하이닉스  KOSPI        186100          2    -4100
# 2  207940  KR7207940008  삼성바이오로직스  KOSPI       1120000          1     4000
# 3  373220  KR7373220003  LG에너지솔루션  KOSPI        332000          2   -20000
# 4  005380  KR7005380001       현대차  KOSPI        190300          2    -2700
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# 0         0.00    53900    55000    53800  18553933  1010214633015
# 1        -2.16   184800   187500   184000   5424556  1006609154400
# 2         0.36  1114000  1145000  1110000     44784    50385061500
# 3        -5.68   351000   351500   332000    361892   121983309750
# 4        -1.40   190000   195100   189200    592292   113369763300
#
#             Marcap      Stocks MarketId
# 0  325353148975000  5969782550      STK
# 1  135481240126500   728002365      STK
# 2   79714880000000    71174000      STK
# 3   77688000000000   234000000      STK
# 4   39851901147300   209416191      STK

# %%
df_KOSPI = fdr.DataReader('KS11', '2024')   # KOSPI
df_Target = fdr.DataReader('005930', '2024')  # Target 종목 : 삼성전자

df_KOSPI.head(10)
# Out:
# 1 001 2024-01-01 00:00:00 2025-12-31 00:00:00
#                Open     High      Low    Close     Volume  Change  UpDown  \
# Date
# 2024-01-02  2645.47  2675.80  2641.88  2669.81  409871688  0.0055       1
# 2024-01-03  2643.54  2643.72  2607.31  2607.31  463131608 -0.0234       2
# 2024-01-04  2592.44  2602.64  2580.09  2587.02  770176172 -0.0078       2
# 2024-01-05  2586.89  2592.29  2572.60  2578.08  522289892 -0.0035       2
# 2024-01-08  2584.23  2591.68  2566.34  2567.82  320143990 -0.0040       2
# 2024-01-09  2598.31  2599.37  2556.00  2561.24  791214273 -0.0026       2
# 2024-01-10  2563.97  2568.19  2539.82  2541.98  570021066 -0.0075       2
# 2024-01-11  2543.03  2557.30  2540.27  2540.27  788422596 -0.0007       2
# 2024-01-12  2536.55  2543.83  2517.76  2525.05  790177187 -0.0060       2
# 2024-01-15  2525.69  2536.06  2515.84  2525.99  802102006  0.0004       1
#
#              Comp          Amount            MarCap
# Date
# 2024-01-02  14.53   9628190129018  2147223894556881
# 2024-01-03 -62.50  10121578328315  2096573473823721
# 2024-01-04 -20.29   8992273956601  2081862659594752
# 2024-01-05  -8.94   8384472928787  2075148802709824
# 2024-01-08 -10.26   6763632029996  2067290656237408
# 2024-01-09  -6.58   8896714487368  2061575745648289
# 2024-01-10 -19.26   8795834820834  2045533566125824
# 2024-01-11  -1.71  13669889824902  2043896294511727
# 2024-01-12 -15.22   8368765827550  2047248114238733
# 2024-01-15   0.94   8182706743844  2047779701417268

# %%
# 동일 카테고리에서 비교군의 설정
object = ['KS11', '207940', '068270', '326030']    # 대형 바이오주 비교

for i in range(len(object)):
    print(str(df_krx[df_krx['Code'] == object[i]]['Name'].values).replace('\'', ''))

# plot legend에 한글 문자열 전달 시 발생하는 기호 제거 방법 (250221) 
result = []

for i in range(len(object)):
    result.append(str(df_krx[df_krx['Code'] == object[i]]['Name'].values).replace('\'', '').replace('[', '').replace(']', ''))

result
# Out:
# []
# [삼성바이오로직스]
# [셀트리온]
# [SK바이오팜]
# ['', '삼성바이오로직스', '셀트리온', 'SK바이오팜']

# %%
# plot에서 한글 폰트 깨짐 문제

import platform

os = platform.system()

# Win
if os == 'Windows':
    plt.rc('font', family = 'Malgun Gothic')

# Mac
elif os == 'Darwin':
    plt.rc('font', family = 'AppleGothic')

# pyplot에서 마이너스 기호 깨지는 문제 (250305)
plt.rcParams['axes.unicode_minus'] = False

# %%
# ARIMA 함수 형태로 정의 - 반복 사용

def cal_residuals(code):
    df = fdr.DataReader(code, '2024')
    series_df = df['Change'].values
    model = ARIMA(series_df, order = (5, 1, 0))
    model_fit = model.fit()
    residuals = DataFrame(model_fit.resid)

    return residuals

# %%
plt.figure(figsize=(10, 5))
ax = plt.gca()

for i in range(len(object)):
    cal_residuals(object[i]).plot(label=object[i], ax=ax)  # 여러 개 중첩

[result[i] for i in range(len(result))]   # legend 리스트 만들기
result[0] = 'KOSPI'    # 공란 처리된 첫번째 칸에 KOSPI 텍스트 입력
plt.legend(result)

plt.show()
# Out:
# 1 001 2024-01-01 00:00:00 2025-12-31 00:00:00

# %%
plt.figure(figsize=(10, 5))
ax = plt.gca()


for i in range(len(object)):
    cal_residuals(object[i]).plot(kind = 'kde', label=object[i], ax=ax)

plt.xlim(-0.1, 0.1)    # 표시 영역을 -10%~+10% 으로 지정

plt.legend(result)
plt.grid(True)

plt.show()
# Out:
# 1 001 2024-01-01 00:00:00 2025-12-31 00:00:00

# %%
# 동일 카테고리 종목의 KDE 비교를 통하여 분석 기간 동안의 변동 특성을 확인할 수 있다.
# KOSPI 지수와의 비교하여 종목의 안정성을 판단하는 기준으로 사용할 수 있으며,
# 금융지주 회사의 분석 건의 경우, 비슷한 배당 수준을 보이는 종목의 경우,
# 안정성을 추구하는 투자자를 위한 종목 선택의 기준으로 사용할 수 있을 것이다.

# %%
# 상세한 변동을 확인할 필요 있음
# 기간 중 최고값을 기준으로 변동 값의 비율을 시계열로 표현

def cal_value(code):
    df = fdr.DataReader(code, '2024')
    series_df = df['Close'].values/max(df['Close'])
    cal_vals = DataFrame(series_df)
    return cal_vals

# %%
plt.figure(figsize=(10, 5))
ax = plt.gca()


for i in range(len(object)):
    cal_value(object[i]).plot(label=object[i], ax=ax)

plt.legend(result)
plt.grid(True)

plt.show()
# Out:
# 1 001 2024-01-01 00:00:00 2025-12-31 00:00:00
